# %% [markdown]
# #**Comunidad Level Up - Intro Python - Clase 1**
# ##Ejercicio 1 - Definir 3 variables (product1, product2, product3) que representen los distintos productos o SKU de un ecommerce y los precios de los mismos (price1, price2, price3)

# %%
product1 = "bateria"
product2 = "cadena"
product3 = "rueda"

price1 = 50000
price2 = 24000
price3 = 70000

# %% [markdown]
# ## Ejercicio 2 - Imprimir en pantalla un mensaje con un texto que indique la promoción de que comprando el producto 1 y el producto 2 se llevarán gratis el producto 3 (e imprimir su precio)

# %%
print (f"Comprando una {product1} y una {product2} se lleva gratis una {product3} al precio de ${price1+price2}")
# Out:
# 'Comprando una bateria y una cadena se lleva gratis una rueda al precio de $74000'

# %% [markdown]
# ##Ejercicio 3 - Define una constante llamada “GRAVITY”, define una variable “b” y asígnale el valor de la constante GRAVITY

# %%
Gravity = 9.81
b = Gravity

# %% [markdown]
# ##Ejercicio 4 - Escribe un programa que solicite al usuario 3 números y muestre la suma en pantalla

# %%
try:
    num1 = float(input("Ingresa el primer número: "))
    num2 = float(input("Ingresa el segundo número: "))
    num3 = float(input("Ingresa el tercer número: "))
    print(f"La suma de los tres números es: {num1+num2+num3}")
except:
    print("Hubo un error")
    print("ingrese un caracter correcto")
# Out:
# Ingresa el primer número: 32
# Ingresa el segundo número: 34
# Ingresa el tercer número: 56
# La suma de los tres números es: 122.0

# %% [markdown]
# ##Ejercicio 5 - Define diferentes variables con los tipos de datos básicos de python: Entero, flotante, texto y booleano e imprimí cada variable en pantalla

# %%
product4 = "faros led"
print (type(product4))
# Out:
# <class 'str'>

# %%
inventario = 40
print (type(inventario))
# Out:
# <class 'int'>

# %%
altura_faro = 0.18
print(type(altura_faro))
# Out:
# <class 'float'>

# %%
Disponibilidad = True
print(type(Disponibilidad))
# Out:
# <class 'bool'>
